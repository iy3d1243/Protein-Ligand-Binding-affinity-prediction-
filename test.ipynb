# %%
import pandas as pd

# %%
# show all rows (no truncation)
pd.set_option("display.max_rows", None)

# optional: show all columns if needed
pd.set_option("display.max_columns", None)

# Show full content of columns
pd.set_option('display.max_colwidth', None)

# %%
df_ki=pd.read_csv('Ki (nM)_only.csv')
# Out:
# C:\Users\iyed\AppData\Local\Temp\ipykernel_24632\3149405642.py:1: DtypeWarning: Columns (8,9,11,15,17,20,21,22,25,29,30,34,35,37,38,47,48,49,50,52,53,54,55,56,57,59,60,61,64,65,66,67,68,69,71,72,73,74,76,77,78,79,80,81,83,84,85,88,89,90,91,92,93,95,96,97,100,101,102,103,104,105,107,108,109,112,113,114,115,116,117,119,120,121,124,125,126,127,128,129,131,132,133,136,137,138,139,140,141,143,144,145,148,149,150,151,152,153,155,156,157,160,161,162,163,164,165,167,168,169,172,173,174,175,176,177,179,180,181,184,185,186,187,188,191,192,193,196,198,199,200,201,203,204,205,208,210,211,212,213,215,216,217,220,222,223,224,225,227,228,229,232,234,235,236,237,239,240,241,244,245,251,252,253,256,263,264,265,268,275,276,277,280,281,287,288,289,292,299,300,301,304,311,312,313) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ki=pd.read_csv('Ki (nM)_only.csv')

# %%
df_ki.shape
# Out:
# (609647, 640)

# %%
df_ki['BindingDB Target Chain Sequence 1'].nunique()
# Out:
# 3729

# %%
df_ki['Ligand SMILES'].nunique()
# Out:
# 251606

# %%
df_ki['Kd (nM)'].isna().sum()
# Out:
# np.int64(609577)

# %%
df_ki['Ligand SMILES'][:1000]
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=O)C(=O)N(CCCCCC(O)=O)[C@@H]1Cc1ccccc1
# ...

# %%
df_kd=pd.read_csv('kd (nM).csv')
# Out:
# C:\Users\iyed\AppData\Local\Temp\ipykernel_24632\1888884558.py:1: DtypeWarning: Columns (7,9,10,13,15,17,20,21,29,30,34,35,37,38,47,48,49,50,52,53,54,55,56,57,59,60,61,64,65,66,67,68,69,76,77,78,79,80,81,83,84,85,88,89,90,91,92,93,100,101,102,103,104,105,112,113,114,115,116,117,124,125,126,127,128,129,136,138,139,140,141,148,149,150,151,152,153,160,161,162,163,164,165,172,173,174,175,176,177,184,185,186,187,188,196,198,199,200,201,208,210,211,212,213,220,222,223,224,225,232,234,235,236,237) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_kd=pd.read_csv('kd (nM).csv')

# %%
df_kd.shape
# Out:
# (118911, 640)

# %%
df_kd['BindingDB Target Chain Sequence 1'].nunique()
# Out:
# 2294

# %%
df_kd['Ki (nM)'].isna().sum()
# Out:
# np.int64(118841)

# %%
df_ki['Kd (nM)'].isna().sum()
# Out:
# np.int64(609577)

# %%
df_ki.shape
# Out:
# (609647, 640)

# %%
df_kd['Ligand SMILES'].nunique()
# Out:
# 34359
